# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import networkx as nx
from scipy.optimize import minimize

from docplex.mp.model import Model
from collections import defaultdict
from openqaoa.problems.converters import FromDocplex2IsingModel # function to translate docplex problems into Ising Hamiltonians

import networkx as nx
import numpy as np
import time
from qiskit import QuantumCircuit, transpile
from qiskit.providers.basic_provider import BasicSimulator

from qiskit_aer import AerSimulator

backend = AerSimulator()

colors = plt.get_cmap("jet", 20)

label_size = 14
plt.rcParams['xtick.labelsize'] = label_size 
plt.rcParams['ytick.labelsize'] = label_size 
plt.rcParams['axes.labelsize'] = label_size 
plt.rcParams['legend.fontsize'] = label_size

# %%
def QUBO(G):
    # WMaxCut model as a QUBO problem
    mdl = Model('MaxCut')
    num_vertices = G.number_of_nodes()
    x = {i: mdl.binary_var(name=f"x_{i}") for i in range(num_vertices)}
    mdl.minimize(-mdl.sum((x[i] * (1 - x[j]) + x[j] * (1 - x[i]))  for i, j in G.edges))
    return mdl

def cost(x, G):
    obj = 0
    for i, j in G.edges():
        if x[i] + x[j] in ["01","10"]:
            obj += 1
    return - obj

def energy(x, hamiltonian):
    obj = 0
    spin = {"1":-1, "0":1}
    for k, v in hamiltonian.items():
        if len(k) == 2:
            obj += v * spin[x[k[0]]] * spin[x[k[1]]]
        elif len(k) == 1:
            obj += v * spin[x[k[0]]]
        else:
            print(k, v)
    return obj


def qaoa_circ(hamiltonian, gammas, betas, n_qubits):
    p = len(gammas)
    qc = QuantumCircuit(n_qubits)
    qc.h(range(n_qubits))
    for ii in range(p):
        for qbits, value in hamiltonian.items():
            if len(qbits) == 1:
                qc.rz(2*gammas[ii]*float(value), qbits[0])
        for qbits, value in hamiltonian.items():
            if len(qbits) == 2:
                qc.rzz(2*gammas[ii]*float(value), *qbits)
        qc.rx(-2*betas[ii], range(n_qubits))
    qc = qc.reverse_bits()
    qc.measure_all()
    return qc

# %%
np.random.seed(1)
problems = np.load("./Data/3MaxCut/problems.npy", allow_pickle=True).item()
# problems = {}
nodes_list_qubo = [40]
random_cases = 10
# Generate graphs with the above condition for different number of nodes
for nodes in nodes_list_qubo: 
    print(f"-------     qubits: {nodes}    ---------")
    problems[nodes] = {}
    for kk in range(random_cases):
        problems[nodes][kk] = {}
        G = nx.random_regular_graph(d=3, n=nodes)
        problems[nodes][kk]["G"] = G
        mdl = QUBO(G)
        ising_hamiltonian = FromDocplex2IsingModel(mdl).ising_model
        max_w = np.max(np.abs(ising_hamiltonian.weights))
        # max_w = np.max(np.abs([w for w, qbs in zip(ising_hamiltonian.weights, ising_hamiltonian.terms) if len(qbs)==2]))
        ising_hamiltonian.weights = [w/max_w for w in ising_hamiltonian.weights]
        ising_hamiltonian.constant = ising_hamiltonian.constant/max_w
        problems[nodes][kk]["ising"] = {tuple(k): v for k, v in zip(ising_hamiltonian.terms, ising_hamiltonian.weights) if abs(v) > 1e-6}
        ti = time.time()
        mdl.solve()
        tf = time.time() - ti
        problems[nodes][kk]["sol"] = "".join(str(round(mdl.solution.get_value(var))) for var in mdl.iter_binary_vars())
        problems[nodes][kk]["opt_cost"] = cost(problems[nodes][kk]["sol"], G)
        problems[nodes][kk]["opt_energy"] = energy(problems[nodes][kk]["sol"], problems[nodes][kk]["ising"])#*max_w + max_w* ising_hamiltonian.constant

# np.save("./Data/3Maxcut/problems.npy", problems)
# Out:
# -------     qubits: 40    ---------

# %%
nx.draw(problems[30][0]["G"])

# %% [markdown]
# # Solving the problem

# %%
method = "hpc"
problems = np.load("./Data/3Maxcut/problems.npy", allow_pickle=True).item()
ps = [10,25,50,100,200]

delta_gammas = {24:[0.4,0.5,0.6,0.7],
                30:[0.7, 0.8, 0.9, 1.0],
                34:[0.5, 0.6, 0.7, 0.8]}
delta_betas = {24:[0.4, 0.6, 0.7, 0.8],
               30:[0.6,0.7,0.8,0.9],
               34:[0.6, 0.7, 0.8, 0.9]}
nqs = [34] 
cases = [0]
shots = 1000
results = np.load("./Data/3Maxcut/results.npy", allow_pickle=True).item()
for nq in nqs:
    print(f"---------   nq = {nq}   --------")
    results[nq] = {}
    for kk in cases:
        print(f"---------   case = {kk}   --------")
        results[nq][kk] = {}
        opt_energy = round(problems[nq][kk]["opt_energy"],3)
        hamiltonian = problems[nq][kk]["ising"]
        G = problems[nq][kk]["G"]
        results[nq][kk]["energies"] = {}
        results[nq][kk]["landscape"]={}
        results[nq][kk]["best"] = {}
        for p in ps:
            best_probability = 0
            print(f"---------   p = {p}   --------")
            results[nq][kk]["energies"][p] = {}
            results[nq][kk]["landscape"][p] = {"energy":np.zeros((len(delta_betas[nq]), len(delta_gammas[nq]))), "probability":np.zeros((len(delta_betas[nq]), len(delta_gammas[nq])))}
            nn = 0
            for i, delta_beta in enumerate(delta_betas[nq]):
                for j, delta_gamma in enumerate(delta_gammas[nq]):
                    if method == "local":
                        gammas = np.arange(1, p+1) * delta_gamma/p
                        betas = np.arange(1, p+1)[::-1] * delta_beta/p
                        qc = qaoa_circ(hamiltonian, gammas, betas, nq)
                        qc = transpile(qc, backend=backend)
                        samples = backend.run(qc, shots=shots).result().get_counts()
                    elif method == "hpc":
                        with open(f"./Data/3Maxcut/samples_hpc/{nq}/{kk}/{p}/{nn}.out", "r") as file:
                            lines = file.readlines()
                        samples = defaultdict(int)
                        for line in lines[2:]:
                            columns = line.split()
                            samples[columns[0][1:-1][::-1]] += int(columns[-1])
                        shots = 10000
                        nn += 1
                    energies = defaultdict(int)
                    mean_energy = 0
                    for sample, c in samples.items():
                        e = round(energy(sample, hamiltonian), 3)
                        energies[e] += c
                        mean_energy += e*c
                    mean_energy /= shots 
                    probability = energies[opt_energy]/shots if opt_energy in energies else 0
                    results[nq][kk]["energies"][p][(delta_beta, delta_gamma)] = energies
                    results[nq][kk]["landscape"][p]["energy"][i,j] = mean_energy
                    results[nq][kk]["landscape"][p]["probability"][i,j] = probability
                    if probability > best_probability:
                        best_probability = probability
                        results[nq][kk]["best"][p] = {"probabiliy":probability, "delta_beta":delta_beta, "delta_gamma":delta_gamma, "energy":mean_energy}
                        print(f"beta:{delta_beta} | gamma: {delta_gamma}, probability: {probability}, mean energy: {mean_energy}")
np.save("./Data/3Maxcut/results.npy", results)
# Out:
# ---------   nq = 34   --------
# ---------   case = 0   --------
# ---------   p = 10   --------
# beta:0.6 | gamma: 0.5, probability: 0.0486, mean energy: -35.121
# beta:0.6 | gamma: 0.6, probability: 0.0495, mean energy: -35.2782
# beta:0.7 | gamma: 0.5, probability: 0.0631, mean energy: -35.5342
# beta:0.7 | gamma: 0.6, probability: 0.0673, mean energy: -35.7856
# beta:0.8 | gamma: 0.6, probability: 0.0778, mean energy: -35.8738
# ---------   p = 25   --------
# beta:0.6 | gamma: 0.5, probability: 0.2628, mean energy: -38.3374
# beta:0.6 | gamma: 0.6, probability: 0.2761, mean energy: -38.427
# beta:0.6 | gamma: 0.7, probability: 0.2808, mean energy: -38.4262
# beta:0.7 | gamma: 0.6, probability: 0.3137, mean energy: -38.6318
# beta:0.7 | gamma: 0.7, probability: 0.3305, mean energy: -38.6886
# beta:0.8 | gamma: 0.6, probability: 0.3414, mean energy: -38.7498
# beta:0.8 | gamma: 0.7, probability: 0.3458, mean energy: -38.7072
# beta:0.9 | gamma: 0.7, probability: 0.3468, mean energy: -38.468
# ---------   p = 50   --------
# beta:0.6 | gamma: 0.5, probability: 0.6042, mean energy: -39.9352
# beta:0.6 | gamma: 0.6, probability: 0.6285, mean energy: -40.03
# beta:0.6 | gamma: 0.7, probability: 0.634, mean energy: -40.0254
# beta:0.7 | gamma: 0.6, probability: 0.6713, mean energy: -40.155
# beta:0.7 | gamma: 0.7, probability: 0.6821, mean energy: -40.1404
# beta:0.8 | gamma: 0.6, probability: 0.6982, mean energy: -40.2132
# beta:0.8 | gamma: 0.7, probability: 0.7074, mean energy: -40.1524
# beta:0.9 | gamma: 0.6, probability: 0.7084, mean energy: -40.1996
# ---------   p = 100   --------
# beta:0.6 | gamma: 0.5, probability: 0.9133, mean energy: -40.814
# beta:0.6 | gamma: 0.6, probability: 0.9244, mean energy: -40.8394
# beta:0.6 | gamma: 0.7, probability: 0.9259, mean energy: -40.8286
# beta:0.7 | gamma: 0.6, probability: 0.9388, mean energy: -40.8662
# beta:0.8 | gamma: 0.6, probability: 0.9445, mean energy: -40.8584
# beta:0.9 | gamma: 0.6, probability: 0.9462, mean energy: -40.8184
# ---------   p = 200   --------
# beta:0.6 | gamma: 0.5, probability: 0.9944, mean energy: -40.9888
# beta:0.6 | gamma: 0.6, probability: 0.9951, mean energy: -40.986
# beta:0.7 | gamma: 0.5, probability: 0.9956, mean energy: -40.9912
# beta:0.7 | gamma: 0.6, probability: 0.9962, mean energy: -40.9842

# %%
ps = [10,25,50,100,200]
method="hpc"
nqs = range(4,21,2)
nqs = [34]
max_nq = 20
cases = range(1, 100)
shots = 1000
results = np.load("./Data/3Maxcut/results.npy", allow_pickle=True).item()
for nq in nqs:
    print(f"---------   nq = {nq}   --------")
    for kk in cases:
        print(f"---------   case = {kk}   --------")
        results[nq][kk] = {}
        opt_energy = round(problems[nq][kk]["opt_energy"],3)
        hamiltonian = problems[nq][kk]["ising"]
        G = problems[nq][kk]["G"]
        results[nq][kk]["best"] = {}
        for p in ps:
            if method == "local":
                if nq > 4 and nq < max_nq: 
                    delta_gamma = np.mean([results[i][0]["best"][p]["delta_gamma"] for i in [nq-2, nq, nq+2]])
                    delta_beta = np.mean([results[i][0]["best"][p]["delta_beta"] for i in [nq-2, nq, nq+2]])
                elif nq == 4:    
                    delta_gamma = np.mean([results[i][0]["best"][p]["delta_gamma"] for i in [nq, nq+2]])
                    delta_beta = np.mean([results[i][0]["best"][p]["delta_beta"] for i in [nq, nq+2]])
                elif nq == max_nq:    
                    delta_gamma = np.mean([results[i][0]["best"][p]["delta_gamma"] for i in [nq-2, nq]])
                    delta_beta = np.mean([results[i][0]["best"][p]["delta_beta"] for i in [nq-2, nq]])
                gammas = np.arange(1, p+1) * delta_gamma/p
                betas = np.arange(1, p+1)[::-1] * delta_beta/p
                qc = qaoa_circ(hamiltonian, gammas, betas, nq)
                qc = transpile(qc, backend=backend)
                samples = backend.run(qc, shots=shots).result().get_counts()
            elif method == "hpc":
                delta_gamma = results[nq][0]["best"][p]["delta_gamma"]
                delta_beta = results[nq][0]["best"][p]["delta_beta"]
                with open(f"./Data/3MaxCut/samples_hpc/{nq}/{kk}/{p}/0.out", "r") as file:
                    lines = file.readlines()
                samples = defaultdict(int)
                for line in lines[2:]:
                    columns = line.split()
                    samples[columns[0][1:-1][::-1]] += int(columns[-1])
                shots = 10_000
            energies = defaultdict(int)
            mean_energy = 0
            for sample, c in samples.items():
                e = round(energy(sample, hamiltonian), 3)
                energies[e] += c
                mean_energy += e*c
            mean_energy /= shots 
            probability = energies[opt_energy]/shots if opt_energy in energies else 0
            results[nq][kk]["best"][p] = {"probabiliy":probability, "delta_beta":delta_beta, "delta_gamma":delta_gamma, "energy":mean_energy}
            print(f"p:{p} | beta:{delta_beta} | gamma: {delta_gamma}, probability: {probability}, mean energy: {mean_energy}")
np.save("./Data/3Maxcut/results.npy", results)
# Out:
# ---------   nq = 34   --------
# ---------   case = 1   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0459, mean energy: -33.8872
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2022, mean energy: -35.8672
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4638, mean energy: -37.4134
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7595, mean energy: -38.3416
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9343, mean energy: -38.8572
# ---------   case = 2   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1069, mean energy: -36.0234
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3472, mean energy: -38.153
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6674, mean energy: -39.8808
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9144, mean energy: -40.6516
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9899, mean energy: -40.9542
# ---------   case = 3   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0797, mean energy: -35.8384
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2693, mean energy: -38.758
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5522, mean energy: -41.1042
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8093, mean energy: -42.3826
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9548, mean energy: -42.8946
# ---------   case = 4   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0369, mean energy: -34.9674
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.172, mean energy: -37.3938
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3996, mean energy: -39.2556
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6705, mean energy: -40.1984
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9013, mean energy: -40.7902
# ---------   case = 5   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0392, mean energy: -35.1876
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1593, mean energy: -37.174
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3761, mean energy: -38.8284
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6751, mean energy: -39.9718
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9021, mean energy: -40.738
# ---------   case = 6   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.2539, mean energy: -35.6238
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.6499, mean energy: -37.653
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.9146, mean energy: -38.7476
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9889, mean energy: -38.9022
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9994, mean energy: -38.9926
# ---------   case = 7   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.2061, mean energy: -33.916
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.6087, mean energy: -35.6894
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.8884, mean energy: -36.7326
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9822, mean energy: -36.9178
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9988, mean energy: -36.9908
# ---------   case = 8   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1937, mean energy: -34.8606
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.5709, mean energy: -37.2322
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.8786, mean energy: -38.6186
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9838, mean energy: -38.8938
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9991, mean energy: -38.9914
# ---------   case = 9   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0451, mean energy: -34.6998
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1814, mean energy: -37.0106
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4468, mean energy: -38.9984
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7466, mean energy: -40.2306
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9339, mean energy: -40.8456
# ---------   case = 10   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0475, mean energy: -35.77
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2012, mean energy: -38.6486
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4575, mean energy: -40.7344
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7174, mean energy: -41.91
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9045, mean energy: -42.6802
# ---------   case = 11   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0888, mean energy: -35.2242
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3108, mean energy: -36.9426
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5554, mean energy: -38.0254
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7972, mean energy: -38.5214
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9513, mean energy: -38.8922
# ---------   case = 12   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.068, mean energy: -33.7304
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2673, mean energy: -35.942
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5653, mean energy: -37.5504
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8595, mean energy: -38.5196
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9822, mean energy: -38.942
# ---------   case = 13   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0274, mean energy: -34.136
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1315, mean energy: -36.045
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3057, mean energy: -37.3378
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6043, mean energy: -38.1264
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9018, mean energy: -38.8006
# ---------   case = 14   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0499, mean energy: -33.5756
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1941, mean energy: -35.7888
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4122, mean energy: -37.3164
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6828, mean energy: -38.2052
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.8876, mean energy: -38.7592
# ---------   case = 15   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0719, mean energy: -34.25
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2526, mean energy: -36.3112
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.521, mean energy: -37.7398
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8064, mean energy: -38.51
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9596, mean energy: -38.9146
# ---------   case = 16   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.088, mean energy: -34.2634
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.354, mean energy: -36.5744
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6714, mean energy: -38.0942
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8959, mean energy: -38.6952
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9858, mean energy: -38.9678
# ---------   case = 17   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.2173, mean energy: -34.1128
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.5825, mean energy: -35.6524
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.8357, mean energy: -36.625
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9681, mean energy: -36.8836
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.998, mean energy: -36.9924
# ---------   case = 18   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1162, mean energy: -34.6394
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.4204, mean energy: -36.8786
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.7679, mean energy: -38.379
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9542, mean energy: -38.8444
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9977, mean energy: -38.9892
# ---------   case = 19   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0253, mean energy: -33.6756
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1585, mean energy: -35.6358
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3974, mean energy: -37.1644
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.782, mean energy: -38.3628
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9592, mean energy: -38.903
# ---------   case = 20   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.114, mean energy: -35.0444
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3888, mean energy: -37.073
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6718, mean energy: -38.2588
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.891, mean energy: -38.7068
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9874, mean energy: -38.969
# ---------   case = 21   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0629, mean energy: -35.6276
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2265, mean energy: -38.078
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4635, mean energy: -39.7096
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.673, mean energy: -40.2492
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.8452, mean energy: -40.6804
# ---------   case = 22   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0756, mean energy: -35.0844
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3135, mean energy: -37.9332
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5743, mean energy: -39.8056
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7811, mean energy: -40.468
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9847, mean energy: -40.9612
# ---------   case = 23   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1073, mean energy: -34.0694
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3391, mean energy: -36.4376
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5977, mean energy: -37.9404
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8339, mean energy: -38.5836
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.964, mean energy: -38.9216
# ---------   case = 24   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.039, mean energy: -35.9424
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2124, mean energy: -39.081
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4729, mean energy: -41.348
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.722, mean energy: -42.2936
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.8992, mean energy: -42.789
# ---------   case = 25   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1407, mean energy: -36.527
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.4831, mean energy: -39.0048
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.8244, mean energy: -40.5044
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9742, mean energy: -40.856
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9989, mean energy: -40.9886
# ---------   case = 26   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0428, mean energy: -34.2194
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1595, mean energy: -36.2014
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3017, mean energy: -37.3986
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.4285, mean energy: -37.7878
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.5467, mean energy: -38.0854
# ---------   case = 27   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0877, mean energy: -34.8044
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3286, mean energy: -36.872
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.544, mean energy: -37.9954
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7456, mean energy: -38.421
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.8923, mean energy: -38.7758
# ---------   case = 28   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0679, mean energy: -36.0658
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2595, mean energy: -39.024
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5566, mean energy: -41.3504
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8426, mean energy: -42.5044
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9706, mean energy: -42.935
# ---------   case = 29   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0437, mean energy: -37.1146
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1938, mean energy: -39.9894
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4538, mean energy: -42.4202
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7313, mean energy: -43.9146
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9125, mean energy: -44.7578
# ---------   case = 30   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0576, mean energy: -34.439
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.25, mean energy: -37.086
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5299, mean energy: -39.1826
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7895, mean energy: -40.297
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9464, mean energy: -40.8596
# ---------   case = 31   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0845, mean energy: -34.627
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3291, mean energy: -36.6624
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6233, mean energy: -38.0674
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8961, mean energy: -38.718
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9897, mean energy: -38.9728
# ---------   case = 32   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1099, mean energy: -33.1586
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.4016, mean energy: -35.0662
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.7285, mean energy: -36.382
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9399, mean energy: -36.8284
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9954, mean energy: -36.9858
# ---------   case = 33   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1077, mean energy: -35.8932
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3985, mean energy: -38.5336
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6791, mean energy: -40.1718
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9012, mean energy: -40.715
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9851, mean energy: -40.9648
# ---------   case = 34   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0535, mean energy: -35.3846
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.191, mean energy: -38.649
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4331, mean energy: -41.0412
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7561, mean energy: -42.284
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.965, mean energy: -42.9148
# ---------   case = 35   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.2691, mean energy: -35.3452
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.6759, mean energy: -37.6644
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.9469, mean energy: -38.8118
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9909, mean energy: -38.9052
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9992, mean energy: -38.9888
# ---------   case = 36   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1451, mean energy: -33.5614
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.4044, mean energy: -35.2164
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6557, mean energy: -36.2364
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.862, mean energy: -36.665
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9731, mean energy: -36.9352
# ---------   case = 37   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0431, mean energy: -35.9636
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.202, mean energy: -38.879
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4666, mean energy: -40.9686
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.735, mean energy: -42.1212
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9223, mean energy: -42.8014
# ---------   case = 38   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0446, mean energy: -33.7286
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1882, mean energy: -35.8276
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4435, mean energy: -37.4472
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7593, mean energy: -38.4052
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9477, mean energy: -38.888
# ---------   case = 39   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.036, mean energy: -35.6288
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1312, mean energy: -37.7972
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.2864, mean energy: -39.2172
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.5291, mean energy: -39.9414
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.7862, mean energy: -40.5586
# ---------   case = 40   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0864, mean energy: -37.0212
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2887, mean energy: -39.6826
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5668, mean energy: -41.5898
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8146, mean energy: -42.433
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9574, mean energy: -42.9
# ---------   case = 41   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0353, mean energy: -34.8946
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1687, mean energy: -37.2898
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4232, mean energy: -39.1436
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7918, mean energy: -40.3574
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9631, mean energy: -40.9076
# ---------   case = 42   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0836, mean energy: -37.3326
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3414, mean energy: -40.2342
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6856, mean energy: -42.0602
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9398, mean energy: -42.7784
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9969, mean energy: -42.9854
# ---------   case = 43   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0339, mean energy: -33.839
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1424, mean energy: -35.7756
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3358, mean energy: -37.136
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6338, mean energy: -38.0332
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.8974, mean energy: -38.7734
# ---------   case = 44   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0352, mean energy: -35.0116
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1869, mean energy: -37.7142
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4709, mean energy: -39.5532
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8308, mean energy: -40.576
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9843, mean energy: -40.962
# ---------   case = 45   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1173, mean energy: -34.2444
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3853, mean energy: -36.647
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6883, mean energy: -38.2226
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9047, mean energy: -38.7348
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9887, mean energy: -38.9698
# ---------   case = 46   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0949, mean energy: -34.4394
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3529, mean energy: -36.6156
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6824, mean energy: -38.1702
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9204, mean energy: -38.7748
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9918, mean energy: -38.9782
# ---------   case = 47   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1734, mean energy: -37.243
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.5165, mean energy: -39.2618
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.8434, mean energy: -40.5642
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9769, mean energy: -40.8646
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9987, mean energy: -40.9856
# ---------   case = 48   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0345, mean energy: -35.6554
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1578, mean energy: -37.7514
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3635, mean energy: -39.3022
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6521, mean energy: -40.1802
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.8905, mean energy: -40.7678
# ---------   case = 49   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1501, mean energy: -34.9672
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.4209, mean energy: -36.8926
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.698, mean energy: -38.2436
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9069, mean energy: -38.7474
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9879, mean energy: -38.9668
# ---------   case = 50   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0419, mean energy: -33.9996
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1446, mean energy: -36.0876
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.307, mean energy: -37.4064
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.486, mean energy: -37.894
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.6924, mean energy: -38.38
# ---------   case = 51   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0822, mean energy: -35.1926
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3235, mean energy: -37.8354
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6319, mean energy: -39.7866
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8853, mean energy: -40.633
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9854, mean energy: -40.9556
# ---------   case = 52   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0501, mean energy: -35.0532
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2262, mean energy: -37.4464
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5047, mean energy: -39.2444
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7806, mean energy: -40.3286
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9408, mean energy: -40.8576
# ---------   case = 53   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0376, mean energy: -35.2354
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1675, mean energy: -37.3238
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3705, mean energy: -38.905
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6102, mean energy: -39.8398
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.824, mean energy: -40.5794
# ---------   case = 54   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.037, mean energy: -34.954
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1998, mean energy: -37.4706
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4729, mean energy: -39.2468
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7853, mean energy: -40.3396
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9556, mean energy: -40.89
# ---------   case = 55   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.067, mean energy: -36.1168
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2636, mean energy: -38.3086
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5197, mean energy: -39.802
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.809, mean energy: -40.5292
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9769, mean energy: -40.9468
# ---------   case = 56   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0476, mean energy: -36.7292
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2254, mean energy: -39.839
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4894, mean energy: -42.4306
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7658, mean energy: -44.0886
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9323, mean energy: -44.8092
# ---------   case = 57   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.164, mean energy: -36.336
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.5082, mean energy: -38.9828
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.819, mean energy: -40.499
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9734, mean energy: -40.8594
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9989, mean energy: -40.9914
# ---------   case = 58   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0656, mean energy: -34.2172
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2429, mean energy: -36.2452
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4961, mean energy: -37.6942
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.806, mean energy: -38.5184
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9646, mean energy: -38.9248
# ---------   case = 59   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0421, mean energy: -35.0938
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1724, mean energy: -37.5658
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3892, mean energy: -39.2338
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6953, mean energy: -40.1752
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9074, mean energy: -40.7864
# ---------   case = 60   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0395, mean energy: -34.7542
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1681, mean energy: -37.2704
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4348, mean energy: -39.1376
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7905, mean energy: -40.3454
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9693, mean energy: -40.9206
# ---------   case = 61   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0975, mean energy: -36.5474
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3676, mean energy: -38.884
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6789, mean energy: -40.252
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9125, mean energy: -40.7384
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9928, mean energy: -40.9764
# ---------   case = 62   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0759, mean energy: -35.7926
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3146, mean energy: -38.328
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6512, mean energy: -40.103
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8934, mean energy: -40.6764
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9817, mean energy: -40.953
# ---------   case = 63   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0471, mean energy: -34.818
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2305, mean energy: -37.5412
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5334, mean energy: -39.541
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8428, mean energy: -40.5216
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9752, mean energy: -40.9354
# ---------   case = 64   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0411, mean energy: -35.635
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1819, mean energy: -38.7658
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4373, mean energy: -41.0776
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8085, mean energy: -42.3894
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9851, mean energy: -42.9564
# ---------   case = 65   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0593, mean energy: -35.7938
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2381, mean energy: -38.8284
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5489, mean energy: -41.2752
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.859, mean energy: -42.5198
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9805, mean energy: -42.9502
# ---------   case = 66   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0841, mean energy: -34.2596
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2801, mean energy: -36.5006
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5102, mean energy: -37.8712
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7578, mean energy: -38.434
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9368, mean energy: -38.8676
# ---------   case = 67   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0457, mean energy: -34.444
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1655, mean energy: -36.3516
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3759, mean energy: -37.596
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6597, mean energy: -38.2546
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.8854, mean energy: -38.7694
# ---------   case = 68   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0341, mean energy: -33.7696
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1352, mean energy: -35.487
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3655, mean energy: -37.0462
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7105, mean energy: -38.1628
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9345, mean energy: -38.8362
# ---------   case = 69   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0537, mean energy: -35.5052
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1972, mean energy: -37.8552
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3818, mean energy: -39.351
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.594, mean energy: -40.064
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.8018, mean energy: -40.5926
# ---------   case = 70   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.2029, mean energy: -35.0884
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.5926, mean energy: -37.3968
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.8914, mean energy: -38.6734
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9852, mean energy: -38.9094
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9994, mean energy: -38.9946
# ---------   case = 71   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0296, mean energy: -34.2152
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1098, mean energy: -36.136
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.2215, mean energy: -37.2184
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.4595, mean energy: -37.8576
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.7445, mean energy: -38.486
# ---------   case = 72   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0408, mean energy: -36.413
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1832, mean energy: -39.3622
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4296, mean energy: -41.3926
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6976, mean energy: -42.2478
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.8894, mean energy: -42.768
# ---------   case = 73   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.054, mean energy: -35.4366
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2443, mean energy: -38.6588
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5711, mean energy: -41.1824
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8429, mean energy: -42.4872
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9681, mean energy: -42.9188
# ---------   case = 74   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0914, mean energy: -36.605
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3693, mean energy: -39.624
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.7082, mean energy: -41.8946
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9022, mean energy: -42.648
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9885, mean energy: -42.9572
# ---------   case = 75   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1534, mean energy: -35.234
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.4668, mean energy: -37.2278
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.797, mean energy: -38.4726
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9653, mean energy: -38.8646
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9986, mean energy: -38.991
# ---------   case = 76   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0575, mean energy: -34.4536
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2537, mean energy: -37.3076
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5483, mean energy: -39.3754
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8369, mean energy: -40.5048
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9698, mean energy: -40.9304
# ---------   case = 77   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0367, mean energy: -35.3672
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1578, mean energy: -37.288
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3571, mean energy: -38.719
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6268, mean energy: -39.7708
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.845, mean energy: -40.561
# ---------   case = 78   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0353, mean energy: -34.873
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1622, mean energy: -37.4288
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3669, mean energy: -39.243
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6763, mean energy: -40.1942
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9315, mean energy: -40.8434
# ---------   case = 79   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1052, mean energy: -35.0338
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3347, mean energy: -37.663
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6259, mean energy: -39.6362
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8668, mean energy: -40.5808
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.979, mean energy: -40.944
# ---------   case = 80   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0424, mean energy: -35.7568
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.162, mean energy: -38.056
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3358, mean energy: -39.4204
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.6534, mean energy: -40.226
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9149, mean energy: -40.8212
# ---------   case = 81   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0588, mean energy: -35.4036
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.253, mean energy: -38.4202
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5456, mean energy: -40.8588
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8203, mean energy: -42.2862
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9564, mean energy: -42.8774
# ---------   case = 82   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0415, mean energy: -36.5878
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1581, mean energy: -39.3964
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3463, mean energy: -41.2492
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.5849, mean energy: -42.0408
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.8127, mean energy: -42.614
# ---------   case = 83   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0386, mean energy: -36.25
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1875, mean energy: -38.6454
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4378, mean energy: -40.6616
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7098, mean energy: -41.8884
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9013, mean energy: -42.6674
# ---------   case = 84   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0921, mean energy: -35.4324
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.362, mean energy: -38.1864
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.7061, mean energy: -40.0706
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9252, mean energy: -40.7622
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9918, mean energy: -40.9762
# ---------   case = 85   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.166, mean energy: -36.7506
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.4872, mean energy: -39.0652
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.7923, mean energy: -40.4576
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9528, mean energy: -40.8148
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9962, mean energy: -40.9812
# ---------   case = 86   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.098, mean energy: -35.966
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3199, mean energy: -38.4254
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5898, mean energy: -39.9902
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.82, mean energy: -40.5482
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9565, mean energy: -40.907
# ---------   case = 87   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1148, mean energy: -35.5652
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.4294, mean energy: -38.5662
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.8046, mean energy: -40.4306
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9741, mean energy: -40.8698
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9983, mean energy: -40.9864
# ---------   case = 88   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0301, mean energy: -34.0758
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1103, mean energy: -35.9346
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.2094, mean energy: -37.1472
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.2637, mean energy: -37.4446
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.2881, mean energy: -37.5716
# ---------   case = 89   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0293, mean energy: -33.943
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1512, mean energy: -36.0306
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3243, mean energy: -37.3824
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.5701, mean energy: -38.0546
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.8182, mean energy: -38.6258
# ---------   case = 90   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0395, mean energy: -35.0738
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.183, mean energy: -37.5606
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.4175, mean energy: -39.4014
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7048, mean energy: -40.3002
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9022, mean energy: -40.7888
# ---------   case = 91   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0889, mean energy: -34.9582
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3004, mean energy: -36.7458
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5391, mean energy: -37.9692
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8068, mean energy: -38.5438
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9675, mean energy: -38.931
# ---------   case = 92   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0793, mean energy: -34.4344
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3365, mean energy: -36.6686
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6384, mean energy: -38.1204
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9098, mean energy: -38.7326
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9911, mean energy: -38.977
# ---------   case = 93   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0781, mean energy: -35.6102
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3089, mean energy: -38.1906
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.637, mean energy: -39.954
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8992, mean energy: -40.6714
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9863, mean energy: -40.9694
# ---------   case = 94   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.2307, mean energy: -33.8326
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.5885, mean energy: -35.6202
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.8711, mean energy: -36.6878
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9808, mean energy: -36.9062
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9994, mean energy: -36.9936
# ---------   case = 95   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0399, mean energy: -35.2994
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.2223, mean energy: -37.6278
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.5177, mean energy: -39.3934
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8023, mean energy: -40.3668
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9521, mean energy: -40.8826
# ---------   case = 96   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.0496, mean energy: -34.6952
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.1899, mean energy: -36.416
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.3882, mean energy: -37.585
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.7577, mean energy: -38.4346
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.976, mean energy: -38.937
# ---------   case = 97   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1523, mean energy: -35.047
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.3981, mean energy: -36.9278
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.6779, mean energy: -38.207
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.8907, mean energy: -38.7074
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9841, mean energy: -38.9612
# ---------   case = 98   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.1673, mean energy: -35.4486
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.4681, mean energy: -37.1492
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.7509, mean energy: -38.3842
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9502, mean energy: -38.8476
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.996, mean energy: -38.984
# ---------   case = 99   --------
# p:10 | beta:0.8 | gamma: 0.6, probability: 0.124, mean energy: -34.9322
# p:25 | beta:0.9 | gamma: 0.7, probability: 0.487, mean energy: -37.2406
# p:50 | beta:0.9 | gamma: 0.6, probability: 0.8177, mean energy: -38.5422
# p:100 | beta:0.9 | gamma: 0.6, probability: 0.9674, mean energy: -38.877
# p:200 | beta:0.7 | gamma: 0.6, probability: 0.9987, mean energy: -38.9936

# %%
fig, ax  = plt.subplots()
sort = defaultdict(dict)
colors = plt.get_cmap("Set2")
for i, p in enumerate([10,25,50,100,200]):
    for nq in sorted(results.keys()):
        y = [results[nq][kk]["best"][p]["probabiliy"] for kk in results[nq].keys()]
        quartiles = np.percentile(np.array(y), [25, 50, 75])
        sort[p][nq] = quartiles[1]
        ax.errorbar(nq, quartiles[1], yerr=[[quartiles[1] - quartiles[0]],[quartiles[2] - quartiles[1]]], marker="o", color=colors(i), capsize=4, markersize=7, markeredgecolor="black")
    ax.errorbar(nq, quartiles[1], yerr=[[quartiles[1] - quartiles[0]],[quartiles[2] - quartiles[1]]], marker="o", color=colors(i), capsize=4, markersize=7, markeredgecolor="black", label=p)

    y_min = [np.min([results[nq][kk]["best"][p]["probabiliy"] for kk in results[nq].keys()]) for nq in sorted(results.keys())]
    std = [np.std([results[nq][kk]["best"][p]["probabiliy"] for kk in results[nq].keys()]) for nq in sorted(results.keys())]
    # plt.errorbar(sorted(results.keys()), y, std , marker="o", label=p, color=colors(3*i), capsize=3)
    ax.plot(sorted(results.keys()), y_min , marker="^", linewidth=0, color=colors(i))
nqs = range(5, 20)
ax.legend()
ax.set_yscale("log")

# %%
def func(x, p, nqs, y_real):
    """C:constant, eta:important value of the scale"""
    eta = x[0]
    C = x[1]
    y_eff = np.array([-eta*(nq - nqs[0]) for nq in nqs])
    return ((y_eff[:-1] - y_real[:-1])**2).mean() +  (y_eff[-1] - y_real[-1])**2

colors = plt.get_cmap("Set2")
ps = [10,25,50,100,200]
etas = {}
Cs = {}
error = {}
fig, ax = plt.subplots(1,2, figsize=(15,5))
for p in ps:
    nqs = list(range(10,21,2)) + [24,30,34]
    y_real = [np.log2(sort[p][nq]/sort[p][nqs[0]]) for nq in nqs]
    x0 = [0.5 , 0.1]
    sol = minimize(func, x0, args=(p, nqs, y_real))
    etas[p] = sol.x[0]
    Cs[p] = sol.x[1]
    error[p] = sol.fun

ax[0].plot(sorted(ps), [etas[p] for p in sorted(ps)], marker="o", linestyle="--")
ax[0].plot(sorted(ps), [etas[ps[0]] for p in sorted(ps)], marker="o", linestyle=":")

for i, p in enumerate(sort.keys()):
    ax[1].plot(nqs, [np.mean(sort[p][nq]) for nq in nqs], marker="o", linewidth=0, color=colors(i))
    ax[1].plot(nqs, [sort[p][nqs[0]] * 2**(-etas[p]*(nq - nqs[0])) for nq in nqs], linestyle="--", color=colors(i))
    # ax[1].plot(nqs, [sort[p][nqs[0]] * 2**(-etas[ps[0]]*(nq - nqs[0])) for nq in nqs], linestyle=":", color=colors(i))

ax[1].set_yscale("log")
ax[1].set_ylabel(r"$probability(x^*)$")
ax[1].set_xlabel(r"$N_q$")
ax[0].set_ylabel(r"$\eta$")
ax[0].set_xlabel(r"$p$")
ax[0].set_yscale("log")
# ax[0].set_ylim(0,10)

# %%
kk = 0
nq = 34
results = np.load("./Data/3Maxcut/results.npy", allow_pickle=True).item()

print(f'gammas = ',{p:results[nq][kk]["best"][p]["delta_gamma"] for p in [10,25,50,100,200]})
print(f'betas = ',{p:results[nq][kk]["best"][p]["delta_beta"] for p in [10,25,50,100,200]})
# Out:
# gammas =  {10: 0.6, 25: 0.7, 50: 0.6, 100: 0.6, 200: 0.6}
# betas =  {10: 0.8, 25: 0.9, 50: 0.9, 100: 0.9, 200: 0.7}

# %%
kk = 0
colors = plt.get_cmap("Set2")
ps = [10 ,25, 50, 100, 200]
for i, p in enumerate(ps):
    plt.plot(sorted(results.keys()), [results[nq][kk]["best"][p]["delta_gamma"] for nq in sorted(results.keys())], marker="o", label=p, color=colors(i))
plt.legend()
plt.ylabel("gamma")
# Out:
# Text(0, 0.5, 'gamma')

# %%
kk = 0
for i, p in enumerate(ps):
    plt.plot(sorted(results.keys()), [results[nq][kk]["best"][p]["delta_beta"] for nq in sorted(results.keys())], marker="o", label=p, color=colors(i))
plt.legend()
plt.ylabel("beta")
# Out:
# Text(0, 0.5, 'beta')

# %%
for i, p in enumerate([10,25,50,100,200]):
    for nq in sorted(results.keys()):
        y = [results[nq][kk]["best"][p]["probabiliy"] for kk in results[nq].keys()]
        quartiles = np.percentile(np.array(y), [25, 50, 75])
        plt.errorbar(nq, quartiles[1], yerr=[[quartiles[1] - quartiles[0]],[quartiles[2] - quartiles[1]]], marker="o", color=colors(3*i), capsize=4, markersize=7, markeredgecolor="black")
    plt.errorbar(nq, quartiles[1], yerr=[[quartiles[1] - quartiles[0]],[quartiles[2] - quartiles[1]]], marker="o", color=colors(3*i), capsize=4, markersize=7, markeredgecolor="black", label=p)

    y_min = [np.min([results[nq][kk]["best"][p]["probabiliy"] for kk in results[nq].keys()]) for nq in sorted(results.keys())]
    std = [np.std([results[nq][kk]["best"][p]["probabiliy"] for kk in results[nq].keys()]) for nq in sorted(results.keys())]
    # plt.errorbar(sorted(results.keys()), y, std , marker="o", label=p, color=colors(3*i), capsize=3)
    plt.plot(sorted(results.keys()), y_min , marker="^", linewidth=0, color=colors(3*i))
nqs = range(5, 20)
plt.plot(nqs, [1/2**nq for nq in nqs], linestyle="--", color="black")
plt.legend()
plt.yscale("log")

# %%
colors = plt.get_cmap("jet", 20)
kk = 0
for nq in results.keys():
    plt.plot(results[nq][kk]["best"].keys(), [results[nq][kk]["best"][p]["delta_gamma"] for p in results[nq][kk]["best"].keys()], marker="o",color= colors(nq-5), label=nq)
plt.legend()

# %%
colors = plt.get_cmap("jet", 20)
kk = 0
for nq in results.keys():
    plt.plot(results[nq][kk]["best"].keys(), [results[nq][kk]["best"][p]["delta_beta"] for p in results[nq][kk]["best"].keys()], marker="o",color= colors(nq), label=nq)
plt.legend()

# %%
for i, p in enumerate(ps):
    plt.plot(results.keys(), [results[nq][kk]["best"][p]["delta_gamma"] for nq in results.keys()], marker="o", label=p, color=colors(3*i))
plt.legend()

# %%
for i, p in enumerate(ps):
    plt.plot(results.keys(), [results[nq][kk]["best"][p]["delta_beta"] for nq in results.keys()], marker="o", label=p, color=colors(3*i))

# %%
p=50
kk = 0
plt.plot(results.keys(), [results[nq][kk]["best"][p]["delta_gamma"] for nq in results.keys()], marker="^")
p=100
kk = 0
plt.plot(results.keys(), [results[nq][kk]["best"][p]["delta_gamma"] for nq in results.keys()], marker="^", linestyle="--")

# %%
p=50
kk = 0
plt.plot(results.keys(), [results[nq][kk]["best"][p]["delta_beta"] for nq in results.keys()], marker="o")
p=100
kk = 0
plt.plot(results.keys(), [results[nq][kk]["best"][p]["delta_beta"] for nq in results.keys()], marker="o", linestyle="--")

# %%
results[nq][kk]["landscape"][p]["energy"]
# Out:
# array([[-5.266266, -5.253113, -5.196792, -5.156203, -5.10733 , -4.98474 ,
#         -4.911587],
#        [-5.270556, -5.284284, -5.28171 , -5.273988, -5.257411, -5.054265,
#         -4.646544],
#        [-5.245391, -5.28457 , -5.282854, -5.277998, -5.166275, -4.703126,
#         -3.80368 ],
#        [-5.208496, -5.283998, -5.280284, -5.228567, -5.073694, -4.118238,
#         -2.830782],
#        [-5.173899, -5.282282, -5.277428, -5.147417, -4.707956, -3.192761,
#         -1.75957 ],
#        [-5.133291, -5.281996, -5.22114 , -4.899973, -4.494245, -2.186405,
#         -0.814943],
#        [-5.100126, -5.278564, -5.136841, -4.709694, -3.688465, -1.258339,
#         -0.206884]])

# %%
p = 100
nq = 18
fig, ax = plt.subplots(1,2)
ax[0].imshow(-results[nq][kk]["landscape"][p]["energy"], vmin=6, vmax=np.max(-results[nq][kk]["landscape"][p]["energy"]))
ax[1].imshow(results[nq][kk]["landscape"][p]["probability"], vmin= 0.8, vmax=np.max(results[nq][kk]["landscape"][p]["probability"]))
